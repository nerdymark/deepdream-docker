# %%
import pandas as pd
import json
import re
from os import walk

def Convert(string): 
    li = list(string.split(" "))
    return li

#topics = []

with open("stevekingia.json", "r") as tweetfile:
    tweets = json.load(tweetfile)
    wordlist = []
    for tweet in tweets:
        words = Convert(tweet['full_text'])
#        for topic in topics:
#            if topic in tweet['full_text'].casefold():
        for word in words:
            word = re.sub(r'''(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'".,<>?«»“”‘’]))''', " ", word)
            word = re.sub('&amp;', '&', word)
            word = re.sub('&quot;', '"', word)
            word = re.sub('&apos;', "'", word)
            word = re.sub('&gt;', '>', word)
            word = re.sub('&lt;', '<', word)
            word = re.sub('"', '', word)
            word = re.sub('"', '', word)
            word = re.sub(r"'", '', word)
            word = re.sub('"', '', word)
            word = re.sub(r'\\n', '', word)
            word = re.sub(r':', '', word)
            word = re.sub('@', '', word)
            word = re.sub('-', '', word)
            word = re.sub('\n', '', word)
            word = re.sub('…', '', word)
            word = re.sub(r'\(', '', word)
            word = re.sub(r'\)', '', word)
            word = re.sub('\.', '', word)
            word = re.sub('&', '', word)
            word = re.sub('\,', '', word)
            word = re.sub('\?', '', word)
            word = re.sub('\!', '', word)
            word = re.sub("\'", '', word)
            word = re.sub("”", '', word)
            word = re.sub("“", '', word)
            word = re.sub("’", '', word)
            word = re.sub("'", '', word)
            word = re.sub("•", '', word)
            word = re.sub("%", '', word)
            word = re.sub("`", '', word)
            if len(word) > 2:
                wordlist.append(word)
        
df = pd.DataFrame(wordlist)

print(wordlist)
# Out:
# ['This', 'terrific', 'minutes', 'why', 'realDonaldTrump', 'POTUSelect', 'Thanks', 'Caroline', 'Did', 'interview', 'with', 'Breitbart', 'yesterday', 'mike_pence', 'America', 'thanx', 'Indiana', 'for', 'sending', 'Congress', 'then', 'Governor', 'Again', 'you', 'lead', 'TedCruz', 'endorsement', 'Allie', 'Beth', 'Stuckey', 'conservmillen', 'lit', 'the', 'room', 'this', 'morning', 'the', 'Conservative', 'Opportunity', 'breakfast', 'Millennials', 'are', 'reversing', 'divorce', 'ratesthe', 'right', 'track', 'for', 'our', 'country', 'Thanks', 'Rising', 'Star', 'RepSteveIsrael', 'Was', 'this', 'bipartisan', 'Partisan', 'then', 'How', 'many', 'Jewish', 'Democrats', 'took', 'walk', 'this', 'event', 'have', 'ProLife/Heartbeat', 'momentum', 'the', 'states', 'Iowa', 'set', 'the', 'pace', 'last', 'year', 'This', 'year', 'multiple', 'states', 'have', '\\or', 'will', 'pass', 'Heartbeat', 'legislation', 'With', 'many', 'states', 'taking', 'action', 'the', 'Supreme', 'Court', 'almost', 'certainly', 'will', 'hear', 'the', 'cases', 'Time', 'put', 'end', 'abortion', 'Bambi', 'grazing', 'just', 'off', 'back', 'deck', 'this', 'morning;', 'watching', 'drink', 'coffee', 'This', 'the', 'day', 'the', 'Lord', 'has', 'made', 'Cochise', 'County', 'Sheriff', 'Mark', 'Dannelsborn', 'Iowa', 'briefing', 'Brisbee', 'May', 'best', 'antidrug', 'smuggler', 'enforcement', 'county', 'Drug', 'mules', 'routinely', 'carry', '100', 'lbs', '4050', 'miles', 'This', 'about', 'lbs', 'back', 'DMRegister', 'Republicans', 'line', 'woo', 'fairgoers', '#iowa', '#tcot', '#statefair', 'will', 'CNN', '900', 'EDT', 'tonight', 'with', 'Chris', 'Cuomo', 'Topics', 'Travel', 'ban', 'Amnesty', 'News', 'the', 'Day', 'When', 'stated', 'that', 'Fords', 'testimony', 'was', 'contrast', 'with', 'Kavanaughs', 'completely', 'uncorroborated', 'was', 'corrected', 'millennial', 'who', 'said', 'Her', 'testimony', 'corroborated', 'her', 'MEMORY', 'wonder', 'what', 'she', 'will', 'think', 'when', 'shes', 'old', 'enough', 'have', 'yearold', 'memories', 'Sanctuary', 'cities', 'counties', 'states', 'violate', 'law', 'and', 'many', 'become', 'lawless', 'nogo', 'zones', 'for', 'local', 'officers', 'too', 'was', 'inevitable', 'Once', 'affirmative', 'action', 'replaced', 'equal', 'opportunity', 'our', 'meritocracy', 'went', 'out', 'the', 'window', 'Merit', 'was', 'replaced', 'minority', 'qualifiers', 'Kavanaugh', 'officially', 'confirmed', 'Thank', 'you', 'every', 'objective', 'Senator', 'God', 'Bless', 'America', 'begin', 'restore', 'the', 'Constitution', 'Todd', 'Longs', 'book', 'Conservative', 'Comeback', 'right', 'ALL', 'issues', 'Todd', 'locked', 'dead', 'heat', 'primary', 'need', 'game', 'changers', 'have', 'read', 'the', 'memo', 'The', 'sickening', 'reality', 'has', 'set', 'longer', 'hold', 'out', 'hope', 'there', 'innocent', 'explanation', 'for', 'the', 'information', 'the', 'public', 'has', 'seen', 'have', 'long', 'said', 'worse', 'than', 'Watergate', 'was', '#neverTrump', '#alwaysHillary', '#releasethememo', 'One', 'year', 'ago', 'today', 'the', 'unconstitutional', 'taking', 'American', 'Liberty', 'was', 'signed', 'ObamaCare', '365', 'days', 'fighting', 'for', 'repeal', 'will', 'Roughing', 'the', 'Pork', 'Tent', 'the', 'Iowa', 'State', 'Fair', 'with', 'the', 'future', 'Fair', 'Queen', 'with', 'Jan', 'Mickelson', 'this', 'morning', 'WHO', 'Listen', 'live', '#tcot', '#iowa', '#who', 'Press', 'conference', 'soon', 'with', '#DonaldTrump', 'here', 'Des', 'Moines', 'Campaign', 'common', 'causes', 'strong', 'robust', 'America', '#Putins', 'bold', 'surprise', 'invasion', 'the', 'Crimean', 'region', 'the', 'sovereign', 'nation', 'state', 'Ukraine', 'feels', 'like', 'Hitlers', 'move', 'into', 'Sudetenland', 'Great', 'time', 'yesterday', '#tcot', '#capntax', 'The', 'attached', 'document', 'disproves', 'NYTimes', 'Negative', 'MisQuote', 'beyond', 'reasonable', 'doubt', 'Wonderful', 'time', 'with', 'living', 'legend', 'Col', 'Bud', 'Day', 'and', 'soldiers', 'from', 'the', '113th', 'and', '185th', 'Saturday', '#i ...

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt 
import time
import random
from os import walk, path
import os
import numpy as np
from PIL import Image
import re

d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()

#outFile = 'wordclouds/'+topic.upper()+'.png'
outFile = 'wordclouds/stevekingia_base.png'
origMask = 'masks/https___cdn.cnn.com_cnnnext_dam_assets_181031170126-01-steve-king-file-1031.jpg'

resizedFile = '/tmp/tmpResize.jpg'

basewidth = 5120
img = Image.open(origMask)
wpercent = (basewidth/float(img.size[0]))
hsize = int((float(img.size[1])*float(wpercent)))
img = img.resize((basewidth,hsize), Image.ANTIALIAS)
img.save(resizedFile)

image_coloring = np.array(Image.open(path.join(d, resizedFile)))



fontpath = 'fonts/'
fontlist = []
for (dirpath, dirnames, filenames) in walk(fontpath):
    fontlist.extend(filenames)
    break
font = random.choice(fontlist)
font = fontpath+font
#font = 'fonts/Dead History Bold.ttf'

#wordlist.remove('cont')

comment_words = ' '

stopwords = set(STOPWORDS)

# iterate through the json file 

for val in df[0]: 
      
    # typecaste each val to string 
    val = str(val)
    # split the value 
    tokens = val.split() 
      
    # Converts each token into lowercase 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower() 
          
    for words in tokens: 
        comment_words = comment_words + words + ' '

#comment_words = re.sub('issue', '', comment_words)
comment_words = re.sub('couple', '', comment_words)

        
print("Word count:", len(comment_words))

wc = WordCloud(width = 5120, height = 2880, 
                background_color ='white', 
                #stopwords = stopwords,
                max_words = 300000,
                font_path = font,
                mask = image_coloring,
                min_font_size = 8,
                #max_font_size = 96,
                random_state = None).generate(comment_words)

image_colors = ImageColorGenerator(image_coloring)




  
# show
fig, axes = plt.subplots(1, 3)
axes[0].imshow(wc, interpolation="bilinear")
# recolor wordcloud and show
# we could also give color_func=image_colors directly in the constructor
axes[1].imshow(wc.recolor(color_func=image_colors), interpolation="bilinear")
axes[2].imshow(image_coloring, cmap=plt.cm.gray, interpolation="bilinear")
for ax in axes:
    ax.set_axis_off()
plt.show()
  
wc.to_file(outFile)
# Out:
# Word count: 267903
